# %%
import pandas as pd 
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
import matplotlib.pyplot as plt
import skimage.io as ioimage_stack
from skimage import data, color
from skimage.transform import rescale, resize, downscale_local_mean

# %matplotlib inline

# %%
img = io.imread("../datasets/acros/photo_112.jfif")
io.imshow(img)

# %%
img_size = 256

# %%
image_resized = resize(img, (img_size, img_size), anti_aliasing=True)
io.imshow(image_resized)

# %%
img = io.imread("../datasets/acros/wwcacro (340).jfif")
print(img.shape)
image_resized = resize(img, (img_size, img_size), anti_aliasing=True)
io.imshow(image_resized)
# Out:
# (144, 180, 3)
