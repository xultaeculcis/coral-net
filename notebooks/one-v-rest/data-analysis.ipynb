# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import skimage.io as io
import sys
from glob import glob
import os, os.path


# %matplotlib inline

data_dir = "../../../datasets/original"


classes = os.listdir(data_dir)

dirs = [data_dir + "/" + c for c in classes ]
dirs
# Out:
# ['../../../datasets/original/other', '../../../datasets/original/acros']

# %%
dic = {}
for dataset_path in dirs:
    path, directories, files = os.walk(dataset_path).__next__()
    dic[dataset_path.split("/")[-1]] = len(files)
    
print(dic)

series = pd.Series(data=dic)
series.plot.bar(figsize=(20,10))

df = series.to_frame()
print(df)

df[0].sum()
# Out:
# {'other': 14168, 'acros': 6865}
#            0
# other  14168
# acros   6865
# 21033
