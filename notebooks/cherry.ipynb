# %%
import pandas as pd

df = pd.read_csv("../datasets/cherrycorals_links_with_categories.csv")

# %%
df.sort_values(by=["year","month", "img_number"]).reset_index().plot(kind="scatter", x="index", y="img_number")
# Out:
# <AxesSubplot:xlabel='index', ylabel='img_number'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1093 entries, 0 to 1092
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_link       1093 non-null   object
#  1   product_name       1093 non-null   object
#  2   categories         1093 non-null   object
#  3   img_url            1093 non-null   object
#  4   year               1093 non-null   int64
#  5   month              1093 non-null   int64
#  6   img_name           1093 non-null   object
#  7   img_base_name      1093 non-null   object
#  8   img_number         1093 non-null   int64
#  9   img_number_suffix  218 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 85.5+ KB

# %%
df[df["img_number"] > 6000]
# Out:
#                                           product_link  \
# 103  https://cherrycorals.com/product/wwc-space-jam...
# 131  https://cherrycorals.com/product/aussie-pink-t...
# 147  https://cherrycorals.com/product/jf-tierra-del...
# 174  https://cherrycorals.com/product/rr-usa-orange...
# 216  https://cherrycorals.com/product/og-green-bali...
# 283  https://cherrycorals.com/product/aussie-green-...
# 299  https://cherrycorals.com/product/arc-fireworks...
# 347  https://cherrycorals.com/product/fragfarmer-re...
# 374  https://cherrycorals.com/product/forest-fire-d...
# 412  https://cherrycorals.com/product/tyree-le-merl...
# 413  https://cherrycorals.com/product/og-garf-bonsa...
# 414  https://cherrycorals.com/product/bioreef-anacr...
# 427  https://cherrycorals.com/product/aussie-highli...
# 529  https://cherrycorals.com/product/aussie-rose-g...
# 599  https://cherrycorals.com/product/bc-magic-wand...
# 667  https://cherrycorals.com/product/rr-nauti-spir...
# ...

# %%
df[df["img_base_name"].str.startswith("CHE")].groupby(["year", "month"])["img_number"].agg(["min", "max"]).reset_index()
# Out:
#    year  month   min   max
# 0  2020      4   604  9989
# 1  2020      5   791  2773
# 2  2020      6  1121  2790
# 3  2020      7  2722  3159
# 4  2020      9  2983  4475
# 5  2020     10  4476  4558

# %%
df[df["img_base_name"].str.startswith("new")].groupby(["year", "month"])["img_number"].agg(["min", "max"]).reset_index()
# Out:
#    year  month    min    max
# 0  2020      3  10370  10370
# 1  2020      6  11361  11361
# 2  2020      7  12083  12199
# 3  2020      8      1      1
# 4  2020      9      2  12285
# 5  2020     10   1096   1169

# %%
df[df["img_base_name"].str.startswith("new")]
# Out:
#                                            product_link  \
# 13    https://cherrycorals.com/product/cr-eternal-fl...
# 21    https://cherrycorals.com/product/aussie-orange...
# 26    https://cherrycorals.com/product/bioreef-anacr...
# 27    https://cherrycorals.com/product/cc-pink-flami...
# 41    https://cherrycorals.com/product/ultra-indo-ac...
# ...                                                 ...
# 1075  https://cherrycorals.com/product/aussie-gold-h...
# 1083  https://cherrycorals.com/product/aussie-green-...
# 1084  https://cherrycorals.com/product/aussie-green-...
# 1086  https://cherrycorals.com/product/tsa-bill-murr...
# 1092  https://cherrycorals.com/product/aussie-gold-h...
#
#                       product_name  \
# 13                CR Eternal Flame
# 21         Aussie Orange Hammer #4
# 26              Bioreef Anacropora
# 27          CC Pink Flamingo Milli
# 41    Ultra Indo Acanthophyllia #2
# ...                            ...
# 1075       Aussie Orange Hammer #2
# ...
